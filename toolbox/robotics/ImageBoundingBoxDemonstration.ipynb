# %%
# %load_ext autoreload
# %autoreload 2

from toolbox.notebook import show_image
from toolbox.robotics import image_bounding_box_manager
print(dir(image_bounding_box_manager))
from toolbox.robotics.image_bounding_box_manager import *
import numpy as np
from scipy.misc import imread
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['BoundingBox', '__builtins__', '__cached__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_handle_section', 'apply_threshold', 'cv2', 'find_contiguous_sections', 'generate_bounding_box', 'get_image_in_bounding_box', 'label', 'np']

# %%
label = np.load('./fixtures/test_label.npy') * 255 #This one is 0-1 range.
image = imread('./fixtures/test_image.png')
print(label.shape)
show_image(label)
print(label.shape)
show_image(image)
# Out:
# (480, 640, 1)
# (480, 640, 1)
# /home/jamesaustin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
sections = find_contiguous_sections(label)
print(sections)
# Out:
# [<BoundingBox - X:104, Y:231, W:145, H:326>, <BoundingBox - X:300, Y:235, W:339, H:331>, <BoundingBox - X:498, Y:238, W:540, H:333>]

# %%
overlayed_image = image.copy()
for i, bbox in enumerate(sections):
    bbox.draw_on_image(overlayed_image, title=i)
show_image(overlayed_image)
# Out:
# kek
# > /home/jamesaustin/code/toolbox/toolbox/robotics/image_bounding_box_manager.py(29)draw_on_image()
# -> cv2.putText(image, str(title),
# (Pdb) c
# kek
# > /home/jamesaustin/code/toolbox/toolbox/robotics/image_bounding_box_manager.py(29)draw_on_image()
# -> cv2.putText(image, str(title),
# (Pdb) c
# kek
# > /home/jamesaustin/code/toolbox/toolbox/robotics/image_bounding_box_manager.py(29)draw_on_image()
# -> cv2.putText(image, str(title),
# (Pdb) c

# %%
for bbox in sections:
    show_image(get_image_in_bounding_box(image, bbox))
